# %% [markdown]
# <a href="https://colab.research.google.com/github/syno3/Data-science-portfolio/blob/main/omeprazole_prophets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Basic omeprazole demand neural-prophet

# %%
from neuralprophet import NeuralProphet
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Omeprazole.csv')
df.head(4)
# Out:
#           ds   y
# 0  6/12/2016  54
# 1  6/19/2016  52
# 2  6/26/2016  49
# 3   7/3/2016  48

# %%
m = NeuralProphet()
metrics = m.fit(df, freq="D")
# Out:
# INFO: nprophet.utils - set_auto_seasonalities: Disabling weekly seasonality. Run NeuralProphet with weekly_seasonality=True to override this.
# INFO: nprophet.utils - set_auto_seasonalities: Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO: nprophet.config - set_auto_batch_epoch: Auto-set batch_size to 8
# INFO: nprophet.config - set_auto_batch_epoch: Auto-set epochs to 123
#   0%|          | 0/100 [00:00<?, ?it/s]
# INFO: nprophet - _lr_range_test: learning rate range test found optimal lr: 6.58E-01
# Epoch[123/123]: 100%|██████████| 123/123 [00:07<00:00, 16.13it/s, SmoothL1Loss=0.0023, MAE=3.03, RegLoss=0]

# %%
future = m.make_future_dataframe(df, periods=365)
forecast = m.predict(future)

# %%
forecasts_plot = m.plot(forecast)

# %%
fig_comp = m.plot_components(forecast)

# %%
fig_param = m.plot_parameters()
