# %% [markdown]
# <a href="https://colab.research.google.com/github/syno3/Data-science-portfolio/blob/main/Neural_prophet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

upload = files.upload()
# Out:
#      <input type="file" id="files-951a8010-aa4b-42c8-8d52-cc60a9838e0c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-951a8010-aa4b-42c8-8d52-cc60a9838e0c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving weatherAUS.csv to weatherAUS.csv

# %%
from neuralprophet import NeuralProphet
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('weatherAUS.csv')
df
# Out:
#               Date Location  MinTemp  ...  Temp3pm  RainToday  RainTomorrow
# 0       2008-12-01   Albury     13.4  ...     21.8         No            No
# 1       2008-12-02   Albury      7.4  ...     24.3         No            No
# 2       2008-12-03   Albury     12.9  ...     23.2         No            No
# 3       2008-12-04   Albury      9.2  ...     26.5         No            No
# 4       2008-12-05   Albury     17.5  ...     29.7         No            No
# ...            ...      ...      ...  ...      ...        ...           ...
# 145455  2017-06-21    Uluru      2.8  ...     22.4         No            No
# 145456  2017-06-22    Uluru      3.6  ...     24.5         No            No
# 145457  2017-06-23    Uluru      5.4  ...     26.1         No            No
# 145458  2017-06-24    Uluru      7.8  ...     26.0         No            No
# 145459  2017-06-25    Uluru     14.9  ...     20.9         No           NaN
#
# [145460 rows x 23 columns]

# %%
df.Location.unique()
# Out:
# array(['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
#        'Newcastle', 'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond',
#        'Sydney', 'SydneyAirport', 'WaggaWagga', 'Williamtown',
#        'Wollongong', 'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat',
#        'Bendigo', 'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura',
#        'Nhil', 'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns',
#        'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa',
#        'Woomera', 'Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport',
#        'Perth', 'SalmonGums', 'Walpole', 'Hobart', 'Launceston',
#        'AliceSprings', 'Darwin', 'Katherine', 'Uluru'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
Albury = df[df['Location'] == 'Albury']
Albury_df = Albury[['Date','Rainfall']]
Albury_df['Date']= pd.to_datetime(Albury_df['Date'])
Albury_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3040 entries, 0 to 3039
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      3040 non-null   datetime64[ns]
#  1   Rainfall  3011 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 71.2 KB
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
Albury_df.describe
# Out:
# <bound method NDFrame.describe of            Date  Rainfall
# 0    2008-12-01       0.6
# 1    2008-12-02       0.0
# 2    2008-12-03       0.0
# 3    2008-12-04       0.0
# 4    2008-12-05       1.0
# ...         ...       ...
# 3035 2017-06-21       0.4
# 3036 2017-06-22       0.0
# 3037 2017-06-23       0.0
# 3038 2017-06-24       0.2
# 3039 2017-06-25       0.0
#
# [3040 rows x 2 columns]>

# %%
Albury_df.isnull().sum()
# Out:
# Date         0
# Rainfall    29
# dtype: int64

# %%
mean = Albury_df['Rainfall'].mean()
Albury_df['Rainfall']= Albury_df['Rainfall'].fillna(mean)
Albury_df.isnull().sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Date        0
# Rainfall    0
# dtype: int64

# %%
Albury_df.columns = ['ds', 'y']
Albury_df
# Out:
#              ds    y
# 0    2008-12-01  0.6
# 1    2008-12-02  0.0
# 2    2008-12-03  0.0
# 3    2008-12-04  0.0
# 4    2008-12-05  1.0
# ...         ...  ...
# 3035 2017-06-21  0.4
# 3036 2017-06-22  0.0
# 3037 2017-06-23  0.0
# 3038 2017-06-24  0.2
# 3039 2017-06-25  0.0
#
# [3040 rows x 2 columns]

# %%
m = NeuralProphet()
metrics = m.fit(Albury_df, freq="D")
# Out:
# INFO: nprophet.utils - set_auto_seasonalities: Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO: nprophet.config - set_auto_batch_epoch: Auto-set batch_size to 32
# INFO: nprophet.config - set_auto_batch_epoch: Auto-set epochs to 21
#   0%|          | 0/100 [00:00<?, ?it/s]
# INFO: nprophet - _lr_range_test: learning rate range test found optimal lr: 3.51E-01
# Epoch[21/21]: 100%|██████████| 21/21 [00:03<00:00,  6.47it/s, SmoothL1Loss=0.189, MAE=2.39, RegLoss=0]

# %%
future = m.make_future_dataframe(Albury_df, periods=365)
forecast = m.predict(future)

# %%
forecasts_plot = m.plot(forecast)

# %%
fig_comp = m.plot_components(forecast)

# %%
fig_param = m.plot_parameters()
